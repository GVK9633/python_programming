# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# Load the image
horse_img = Image.open(r'C:\Users\RENUKA\OneDrive\Desktop\horse.jpeg')  # Correct the path if needed

# Display the image using Matplotlib
plt.imshow(horse_img)  # Use imshow to display the image
# plt.axis('off')        # Optional: Turn off the axis for a cleaner look
plt.show()
