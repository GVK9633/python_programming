# %%
x,y= input("enter values: ").split()
print("x:", x, "y:", y)
# Out:
# x: 23 y: 45

# %%
age_input = input("Enter your age: ")
age = int(age_input)
if age >= 18:
    print("You are eligible to vote.")
else:
    print("You are not eligible to vote.")
# Out:
# You are not eligible to vote.

# %%
amount = 15078.758
print("amount is ${:.2f}".format(amount))
# Out:
# amount is $15078.76

# %%
print("Python",end='@')
print("programming")
print('a','v','c',sep='-')
# Out:
# Python@programming
# a-v-c

# %%
name="viijay"
age=23
print(f"my name is {name} and my age is {age}")
# Out:
# my name is viijay and my age is 23
