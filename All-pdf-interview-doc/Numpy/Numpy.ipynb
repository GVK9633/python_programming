# %% [markdown]
# Great! Here's a comprehensive list of **100 NumPy interview questions and answers**, categorized from **beginner to experienced level**, complete with **examples and sample data** to help you master NumPy for interviews.
#
# ---
#
# ## 📘 **NumPy 100 Interview Questions & Answers**
#
# Divided into:
#
# * 🟢 Beginner (1–30)
# * 🟡 Intermediate (31–70)
# * 🔴 Advanced (71–100)
#
# ---
#
# ## 🟢 **Beginner Level (1–30)**
#
# ---
#
# ### 1. What is NumPy?
#
# **Answer:** NumPy (Numerical Python) is a Python library used for numerical computations with support for large multi-dimensional arrays and matrices.
#
# ```python
# import numpy as np
# ```
#
# ---
#
# ### 2. How to create a NumPy array?
#
# ```python
# arr = np.array([1, 2, 3])
# ```
#
# ---
#
# ### 3. What is the difference between a list and a NumPy array?
#
# **Answer:** Arrays are more efficient and support element-wise operations.
#
# ```python
# list1 = [1, 2, 3]
# arr1 = np.array(list1)
# ```
#
# ---
#
# ### 4. How to check the shape of an array?
#
# ```python
# arr.shape
# ```
#
# ---
#
# ### 5. How to check the data type?
#
# ```python
# arr.dtype
# ```
#
# ---
#
# ### 6. How to create a 2D array?
#
# ```python
# arr2d = np.array([[1, 2], [3, 4]])
# ```
#
# ---
#
# ### 7. How to create an array of zeros?
#
# ```python
# np.zeros((2, 3))
# ```
#
# ---
#
# ### 8. How to create an array of ones?
#
# ```python
# np.ones((3, 2))
# ```
#
# ---
#
# ### 9. How to create an array with a range?
#
# ```python
# np.arange(1, 10, 2)
# ```
#
# ---
#
# ### 10. How to create an array with evenly spaced numbers?
#
# ```python
# np.linspace(0, 1, 5)
# ```
#
# ---
#
# ### 11. How to reshape an array?
#
# ```python
# arr = np.arange(6).reshape(2, 3)
# ```
#
# ---
#
# ### 12. How to flatten a multi-dimensional array?
#
# ```python
# arr.flatten()
# ```
#
# ---
#
# ### 13. How to generate a random array?
#
# ```python
# np.random.rand(2, 3)
# ```
#
# ---
#
# ### 14. What is the difference between `rand`, `randn`, and `randint`?
#
# * `rand`: Uniform \[0, 1)
# * `randn`: Standard normal
# * `randint`: Random integers
#
# ```python
# np.random.randint(1, 10, size=(2,2))
# ```
#
# ---
#
# ### 15. How to set a seed for reproducibility?
#
# ```python
# np.random.seed(42)
# ```
#
# ---
#
# ### 16. How to access elements in an array?
#
# ```python
# arr[0, 1]  # row 0, col 1
# ```
#
# ---
#
# ### 17. How to slice an array?
#
# ```python
# arr[:, 1]  # all rows, 2nd column
# ```
#
# ---
#
# ### 18. How to perform element-wise addition?
#
# ```python
# a + b
# ```
#
# ---
#
# ### 19. How to perform element-wise multiplication?
#
# ```python
# a * b
# ```
#
# ---
#
# ### 20. How to perform matrix multiplication?
#
# ```python
# np.dot(a, b)
# ```
#
# ---
#
# ### 21. How to compute mean, median, sum?
#
# ```python
# arr.mean(), np.median(arr), arr.sum()
# ```
#
# ---
#
# ### 22. How to compute standard deviation?
#
# ```python
# arr.std()
# ```
#
# ---
#
# ### 23. How to transpose a matrix?
#
# ```python
# arr.T
# ```
#
# ---
#
# ### 24. How to find max and min?
#
# ```python
# arr.max(), arr.min()
# ```
#
# ---
#
# ### 25. How to get index of max/min?
#
# ```python
# arr.argmax(), arr.argmin()
# ```
#
# ---
#
# ### 26. How to create an identity matrix?
#
# ```python
# np.eye(3)
# ```
#
# ---
#
# ### 27. How to check if any/all elements are true?
#
# ```python
# arr.any(), arr.all()
# ```
#
# ---
#
# ### 28. How to compare arrays?
#
# ```python
# np.array_equal(a, b)
# ```
#
# ---
#
# ### 29. How to round values?
#
# ```python
# np.round(arr, 2)
# ```
#
# ---
#
# ### 30. How to convert array to list?
#
# ```python
# arr.tolist()
# ```
#
# ---
#
# ## 🟡 **Intermediate Level (31–70)**
#
# Would you like me to continue with questions **31–100** covering intermediate and advanced topics?
#
# These include:
#
# * Boolean indexing
# * Broadcasting
# * NaN handling
# * Set operations
# * Performance tips
# * Vectorization
# * Custom functions with `np.vectorize`
# * Memory layout and strides
#
# Let me know and I’ll send the rest in a structured format.

# %% [markdown]
# Awesome! Let's continue with the **Intermediate (31–70)** and **Advanced (71–100)** level **NumPy interview questions and answers**, all with examples. This builds directly on the beginner concepts.
#
# ---
#
# ## 🟡 **Intermediate Level (31–70)**
#
# ---
#
# ### 31. What is broadcasting in NumPy?
#
# **Answer:** Automatically expands arrays of different shapes during operations.
#
# ```python
# a = np.array([[1], [2], [3]])
# b = np.array([10, 20, 30])
# result = a + b
# ```
#
# ---
#
# ### 32. How to perform boolean indexing?
#
# ```python
# arr[arr > 5]
# ```
#
# ---
#
# ### 33. How to replace elements based on condition?
#
# ```python
# arr[arr < 5] = 0
# ```
#
# ---
#
# ### 34. How to extract diagonal from a matrix?
#
# ```python
# np.diag(arr)
# ```
#
# ---
#
# ### 35. How to find unique values?
#
# ```python
# np.unique(arr)
# ```
#
# ---
#
# ### 36. How to check for NaN values?
#
# ```python
# np.isnan(arr)
# ```
#
# ---
#
# ### 37. How to fill NaN with a specific value?
#
# ```python
# arr = np.where(np.isnan(arr), 0, arr)
# ```
#
# ---
#
# ### 38. How to remove duplicate rows?
#
# ```python
# np.unique(arr, axis=0)
# ```
#
# ---
#
# ### 39. How to stack arrays vertically and horizontally?
#
# ```python
# np.vstack([a, b])
# np.hstack([a, b])
# ```
#
# ---
#
# ### 40. How to split arrays?
#
# ```python
# np.split(arr, 2)
# ```
#
# ---
#
# ### 41. What is `np.where()` used for?
#
# ```python
# np.where(arr > 5, 'High', 'Low')
# ```
#
# ---
#
# ### 42. What is the difference between copy and view?
#
# ```python
# a = np.array([1, 2, 3])
# b = a.view()
# c = a.copy()
# ```
#
# ---
#
# ### 43. How to sort a NumPy array?
#
# ```python
# np.sort(arr)
# ```
#
# ---
#
# ### 44. How to sort by column?
#
# ```python
# arr[arr[:, 1].argsort()]
# ```
#
# ---
#
# ### 45. How to reverse an array?
#
# ```python
# arr[::-1]
# ```
#
# ---
#
# ### 46. What is `axis` in NumPy functions?
#
# * `axis=0`: down rows (column-wise)
# * `axis=1`: across columns (row-wise)
#
# ```python
# arr.sum(axis=0)
# ```
#
# ---
#
# ### 47. How to compute row-wise or column-wise mean?
#
# ```python
# arr.mean(axis=0)  # Columns
# arr.mean(axis=1)  # Rows
# ```
#
# ---
#
# ### 48. How to pad an array?
#
# ```python
# np.pad(arr, pad_width=1, mode='constant', constant_values=0)
# ```
#
# ---
#
# ### 49. How to find cumulative sum or product?
#
# ```python
# arr.cumsum()
# arr.cumprod()
# ```
#
# ---
#
# ### 50. How to calculate differences between elements?
#
# ```python
# np.diff(arr)
# ```
#
# ---
#
# ### 51. How to tile or repeat an array?
#
# ```python
# np.tile([1, 2], 3)      # [1, 2, 1, 2, 1, 2]
# np.repeat([1, 2], 3)    # [1, 1, 1, 2, 2, 2]
# ```
#
# ---
#
# ### 52. How to apply a function element-wise?
#
# ```python
# f = np.vectorize(lambda x: x**2)
# f(arr)
# ```
#
# ---
#
# ### 53. How to create a masked array?
#
# ```python
# masked = np.ma.masked_where(arr > 5, arr)
# ```
#
# ---
#
# ### 54. What are structured arrays?
#
# ```python
# data = np.array([(1, 'A'), (2, 'B')], dtype=[('id', 'i4'), ('name', 'U1')])
# ```
#
# ---
#
# ### 55. How to simulate coin toss or dice roll?
#
# ```python
# np.random.choice(['H', 'T'], size=10)
# np.random.randint(1, 7, 5)
# ```
#
# ---
#
# ### 56. How to create a histogram with NumPy?
#
# ```python
# np.histogram(arr, bins=5)
# ```
#
# ---
#
# ### 57. How to calculate dot product of vectors?
#
# ```python
# np.dot(a, b)
# ```
#
# ---
#
# ### 58. How to calculate cross product?
#
# ```python
# np.cross(a, b)
# ```
#
# ---
#
# ### 59. How to normalize an array?
#
# ```python
# arr = arr / np.linalg.norm(arr)
# ```
#
# ---
#
# ### 60. What is broadcasting error and how to fix it?
#
# **Answer:** Happens when array shapes are incompatible. Fix by reshaping.
#
# ---
#
# ### 61. How to reshape using `reshape(-1, 1)`?
#
# ```python
# arr.reshape(-1, 1)  # Make column vector
# ```
#
# ---
#
# ### 62. How to apply matrix inverse?
#
# ```python
# np.linalg.inv(np.array([[1, 2], [3, 4]]))
# ```
#
# ---
#
# ### 63. How to calculate determinant?
#
# ```python
# np.linalg.det(arr)
# ```
#
# ---
#
# ### 64. How to solve a system of linear equations?
#
# ```python
# # Ax = b
# A = np.array([[2, 1], [1, 3]])
# b = np.array([8, 13])
# np.linalg.solve(A, b)
# ```
#
# ---
#
# ### 65. How to compute eigenvalues and eigenvectors?
#
# ```python
# np.linalg.eig(arr)
# ```
#
# ---
#
# ### 66. How to get memory size of array?
#
# ```python
# arr.nbytes
# ```
#
# ---
#
# ### 67. What is `.itemsize`, `.size`, `.shape`?
#
# ```python
# arr.itemsize  # bytes per element
# arr.size      # total elements
# arr.shape     # dimensions
# ```
#
# ---
#
# ### 68. How to transpose a 3D array?
#
# ```python
# np.transpose(arr, (0, 2, 1))
# ```
#
# ---
#
# ### 69. How to use `np.clip()`?
#
# ```python
# np.clip(arr, 0, 100)  # Limit values
# ```
#
# ---
#
# ### 70. How to create a boolean mask?
#
# ```python
# mask = (arr > 10) & (arr < 50)
# ```
#
# ---
#
# ## 🔴 **Advanced Level (71–100)**
#
# Would you like me to continue with the **Advanced (71–100)** level now?
#
# These include:
#
# * Broadcasting tricks
# * Vectorized performance
# * Strides and views
# * Complex number support
# * Performance tuning
# * Advanced indexing
# * Interview puzzle questions
#
# Let me know and I’ll send the final set!
