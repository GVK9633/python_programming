# %% [markdown]
# # https://github.com/kodigitaccount/AGENTIC_AI/tree/main

# %%
# !pip install env
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   DEPRECATION: Building 'env' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'env'. Discussion can be found at https://github.com/pypa/pip/issues/6334
# ...
#   Created wheel for env: filename=env-0.1.0-py3-none-any.whl size=2013 sha256=d0c120837f7ed7ab7d5ca38543a9e521a3087e86a0aa816a1ccbf28efa0aacfe
#   Stored in directory: /Users/gvijaykumarachary/Library/Caches/pip/wheels/f2/0a/55/c971729efb2d554c110d5d852b0e891e44da5ae8503208228e
# Successfully built env
# ...

# %%
# !pip install phidata
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 716.9/716.9 kB 8.7 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [phidata]m2/3 [phidata]
# ...

# %%
# !pip uninstall phi
# Out:
# Found existing installation: phi 0.6.7
# Uninstalling phi-0.6.7:
#   Would remove:
#     /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages/phi-0.6.7.dist-info/*
#     /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages/phi/*
#   Would not remove (might be manually added):
#     /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages/phi/agent/__init__.py
#     /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages/phi/agent/agent.py
#     /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages/phi/agent/duckdb.py
#     /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages/phi/agent/python.py
#     /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages/phi/agent/session.py
#     /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages/phi/api/__init__.py
# ...

# %%
from phi.agent import Agent
from phi.model.groq import Groq
from dontenv import load_dotenv
load_dotenv()
agent = Agent(
    model=Groq(id="groq/groq-phi-2-7b"),
    markdown=True,
    ),
agent.print_response("future of agentic aI")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from phi.agent import Agent
#       2 from phi.model.groq import Groq
#       3 from dontenv import load_dotenv
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/phi/agent/__init__.py:1
# ----> 1 from phi.agent.agent import (
#       2     Agent,
#       3     AgentKnowledge,
#       4     AgentMemory,
#       5     AgentSession,
#       6     AgentStorage,
#       7     Function,
#       8     MemoryRetrieval,
#       9     Message,
#      10     RunEvent,
#      11     RunResponse,
#      12     Tool,
#      13     Toolkit,
#      14 )
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/phi/agent/agent.py:33
#      31 from phi.model.content import Image, Video, Audio
#      32 from phi.reasoning.step import ReasoningStep, ReasoningSteps, NextAction
# ...
