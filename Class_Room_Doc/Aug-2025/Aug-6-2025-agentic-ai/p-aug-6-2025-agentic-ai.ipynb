# %%
# !pip install litellm
# Out:
# ...
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 10.2 MB/s  0:00:00 eta 0:00:01
# ...
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [litellm]m7/8 [litellm]
# ...

# %%
# !pip install gradio
# Out:
# ...
#   Using cached typer-0.16.0-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 MB 8.8 MB/s  0:00:06m0:00:0100:01m
# ...
# Using cached typer-0.16.0-py3-none-any.whl (46 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 873.0/873.0 kB 5.6 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 7.8 MB/s  0:00:01 eta 0:00:01
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15/15 [gradio]14/15 [gradio]
# ...

# %%
# !pip install google-generativeai
# Out:
# ...
#   Using cached google_generativeai-0.8.5-py3-none-any.whl.metadata (3.9 kB)
# ...
#   Using cached google_ai_generativelanguage-0.6.15-py3-none-any.whl.metadata (5.7 kB)
# ...
#   Using cached httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# ...
# Using cached google_generativeai-0.8.5-py3-none-any.whl (155 kB)
# Using cached google_ai_generativelanguage-0.6.15-py3-none-any.whl (1.3 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 9.9 MB/s  0:00:01m eta 0:00:01
# Using cached google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Using cached httplib2-0.22.0-py3-none-any.whl (96 kB)
# ...
#   Attempting uninstall: google-ai-generativelanguage
#     Found existing installation: google-ai-generativelanguage 0.6.18
#     Uninstalling google-ai-generativelanguage-0.6.18:━━━━━━━━━━━━━ 4/6 [google-ai-generativelanguage]
# ...

# %%
import os
import litellm
import gradio as gr
from smolagents import CodeAgent,DuckDuckGoSearchTool,HfApiModel,LiteLLMModel
import  google.generativeai as genai

# %%
litellm._turn_on_debug()

# %%
os.environ["GOOGLE_API_KEY"] = ""
genai.configure(api_key=os.environ["GOOGLE_API_KEY"])

# %%
# model = LiteLLMModel(model="google/gemini-1.5-flash-002", 
#                     api_key=os.environ["GOOGLE_API_KEY"])

# %%
model = LiteLLMModel(model="google/gemini-1.5-flash", 
                    api_key=os.environ["GOOGLE_API_KEY"])
# Out:
# /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages/smolagents/models.py:991: FutureWarning: The 'model_id' parameter will be required in version 2.0.0. Please update your code to pass this parameter to avoid future errors. For now, it defaults to 'anthropic/claude-3-5-sonnet-20240620'.
#   warnings.warn(

# %%
ml_code_agent = CodeAgent(
    tools=[DuckDuckGoSearchTool()],
    model=model,
    additional_authorized_imports=['pandas', 'numpy', 'matplotlib', 'seaborn','sklearn','json'],
)
