# %% [markdown]
# https://www.llama.com/docs/how-to-guides/fine-tuning/
#
# git clone https://github.com/artidoro/qlora
#
# what is hallucination

# %% [markdown]
# Please work on attached file and also below link is for course certification -->
#
# •Google Data Analytics certification
# https://cloud.google.com/data-science
#
# •Microsoft Certification
# https://learn.microsoft.com/en-us/training/browse/
# •IBM
# Data Science è
# https://www.coursera.org/professional-certificates/ibm-data-science•Kaggle
# Certification è
# https://www.kaggle.com/learn/intro-to-machine-learning
# •Linkedin Learning àhttps://www.linkedin.com/learning
