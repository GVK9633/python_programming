# %%
def cat_hat(str):
  ##your code here##
  ##You need to write complete code this time 
  if("cat" in str and "hat" in str ):
      return True
  else:
      return False
  
print(cat_hat("The cat in the ha1."))
# Out:
# False
