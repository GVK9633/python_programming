# %%
#pip install -q -U google-generativeai
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import google.generativeai as genai
genai.configure(api_key='AIzaSyAq8GEENnN-xdU7n9dMbGQszQKehVzaLBg')
model= genai.GenerativeModel('gemini-2.0-flash')
response = model.generate_content("what is model context protocol can you explain to school student")
print(response.text)
# Out:
# Okay, imagine you're writing a story with your friends. To make sure everyone is on the same page and the story makes sense, you need some shared information. This information might include:
#
# *   **The setting:** Is it a fantasy world, a futuristic city, or a small town?
# *   **The characters:** Who are they? What are their personalities and relationships?
# *   **The plot:** What's the main problem or goal of the story?
# *   **The rules:** Are there any special rules or magic systems in your world?
#
# You all keep this information in your head, or maybe you write it down together. This shared information is like the **context** of your story.
#
# Now, think about computer programs, especially AI models like ChatGPT. They also need context to understand what you're asking them and to give you a good answer.
#
# **Model Context Protocol (MCP) - In simple terms**
#
# MCP is like a set of guidelines or rules that help different computer programs (like different AI models or even different parts of the same AI model) share and understand the **context** of a task or conversation.
#
# **Here's a more detailed analogy:**
#
# Imagine you have two robots working together to build a LEGO castle.
#
# *   **Robot A:** Knows how to pick up and place LEGO bricks.
# *   **Robot B:** Knows how to read blueprints (instructions) for the castle.
#
# To build the castle successfully, they need to share information:
#
# *   **What kind of LEGO bricks are available?** (e.g., colors, sizes)
# *   **Which section of the castle are they working on?** (e.g., the gate, a tower)
# *   **What are the specific instructions for this section?** (e.g., place a blue brick on top of a red brick)
#
# MCP would be like the set of instructions that tells Robot A and Robot B *how* to share this information with each other so they can work together efficiently.  It defines the *format* and *meaning* of the shared information.
#
# **Why is MCP important?**
#
# *   **Helps AI models understand what you mean:**  Without context, an AI model might misunderstand your request. MCP ensures that the model has the necessary information to interpret your question correctly.
# *   **Makes AI models more consistent:** With MCP, different AI models or different parts of the same AI model will all be working with the same understanding of the context, leading to more consistent and reliable results.
# *   **Enables AI models to work together better:** When different AI models can easily share context using MCP, they can collaborate on complex tasks more effectively.
# *   **Helps AI models respond like it remembers past conversations** Imagine ChatGPT remembers what you talked about 2 messages ago! Context allows for that.
#
# **Think of it this way:**
#
# Just like knowing the setting, characters, and plot helps you write a good story with your friends, MCP helps AI models understand the situation and give you the best possible answer.
#
# **In a nutshell:**
#
# Model Context Protocol (MCP) is a way for different computer programs, especially AI models, to share and understand the necessary background information to work together effectively. It is like setting the stage for a play, so that all actors can understand their roles.
