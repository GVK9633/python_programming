# %%
# AIzaSyAq8GEENnN-xdU7n9dMbGQszQKehVzaLBg
# pip install -qU "langchain[google-genai]"

import getpass
import os

if not os.environ.get("GOOGLE_API_KEY"):
  os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter API key for Google Gemini: ")

from langchain.chat_models import init_chat_model

model = init_chat_model("gemini-2.0-flash", model_provider="google_genai")

# %%
from langchain_core.messages import HumanMessage, SystemMessage

messages = [
    SystemMessage("Translate the following from English into Hindhi"),
    HumanMessage("How are you!"),
]

model.invoke(messages)
# Out:
# AIMessage(content='Here are a few ways to translate "How are you!" into Hindi, depending on the level of formality you want to convey:\n\n*   **आप कैसे हैं?** (Aap kaise hain?) - This is the most common and polite way to ask "How are you?" It\'s suitable for most situations, especially when speaking to someone you don\'t know well or someone older than you.\n\n*   **क्या हाल है?** (Kya haal hai?) - This is a more casual way of asking "How are you?" It\'s suitable for friends and acquaintances.\n\n*   **कैसे हो?** (Kaise ho?) - This is an informal way of asking "How are you?" It\'s generally used with close friends and family members.\n\n*   **और क्या चल रहा है?** (Aur kya chal raha hai?) - This translates to "And what\'s going on?" and can be used as a greeting similar to "How are you?" in informal settings.\n\nTherefore, the best option depends on who you are talking to.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--c9e30d22-58d6-46c2-9be0-f0c791a37fe8-0', usage_metadata={'input_tokens': 12, 'output_tokens': 224, 'total_tokens': 236, 'input_token_details': {'cache_read': 0}})

# %%
model.invoke("Hello")

model.invoke([{"role": "user", "content": "Hello"}])

model.invoke([HumanMessage("Hello")])
# Out:
# AIMessage(content='Hello there! How can I help you today?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--15589770-c450-4c2f-9bcf-db0de19f4f78-0', usage_metadata={'input_tokens': 1, 'output_tokens': 11, 'total_tokens': 12, 'input_token_details': {'cache_read': 0}})

# %%
# promprt template

# %%
from langchain_core.prompts import ChatPromptTemplate

system_template = "Translate the following from English into {language}"

prompt_template = ChatPromptTemplate.from_messages(
    [("system", system_template), ("user", "{text}")]
)

# %%
prompt = prompt_template.invoke({"language": "odia", "text": "how are you!"})

prompt
# Out:
# ChatPromptValue(messages=[SystemMessage(content='Translate the following from English into odia', additional_kwargs={}, response_metadata={}), HumanMessage(content='how are you!', additional_kwargs={}, response_metadata={})])

# %%
prompt.to_messages()
# Out:
# [SystemMessage(content='Translate the following from English into odia', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='how are you!', additional_kwargs={}, response_metadata={})]

# %%
response = model.invoke(prompt)
print(response.content)
# Out:
# ଆପଣ କେମିତି ଅଛନ୍ତି! (Aapana kemiti achanti!)
