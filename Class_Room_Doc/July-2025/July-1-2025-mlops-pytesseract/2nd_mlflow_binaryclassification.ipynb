# %%
import numpy as np
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report
import warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# Cell In[1], line 6
#       4 from sklearn.linear_model import LogisticRegression
#       5 from sklearn.ensemble import RandomForestClassifier
# ----> 6 from xgboost import XGBClassifier
#       7 from sklearn.metrics import classification_report
#       8 import warnings
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/xgboost/__init__.py:6
#       1 """XGBoost: eXtreme Gradient Boosting library.
#       2
#       3 Contributors: https://github.com/dmlc/xgboost/blob/master/CONTRIBUTORS.md
#       4 """
# ----> 6 from . import tracker  # noqa
#       7 from . import collective
#       8 from .core import (
#       9     Booster,
#      10     DataIter,
#    (...)
#      15     build_info,
#      16 )
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/xgboost/tracker.py:9
#       6 from enum import IntEnum, unique
#       7 from typing import Dict, Optional, Union
# ----> 9 from .core import _LIB, _check_call, _deprecate_positional_args, make_jcargs
#      12 def get_family(addr: str) -> int:
#      13     """Get network family from address."""
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/xgboost/core.py:295
#     291     return lib
#     294 # load the XGBoost library globally
# --> 295 _LIB = _load_lib()
#     298 def _check_call(ret: int) -> None:
#     299     """Check the return value of C API call
#     300
#     301     This function will raise exception when error occurs.
#    (...)
#     307         return value from API calls
#     308     """
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/xgboost/core.py:257, in _load_lib()
#     255     if not lib_success:
#     256         libname = os.path.basename(lib_paths[0])
# --> 257         raise XGBoostError(
#     258             f"""
#     259 XGBoost Library ({libname}) could not be loaded.
#     260 Likely causes:
#     261   * OpenMP runtime is not installed
#     262     - vcomp140.dll or libgomp-1.dll for Windows
#     263     - libomp.dylib for Mac OSX
#     264     - libgomp.so for Linux and other UNIX-like OSes
#     265     Mac OSX users: Run `brew install libomp` to install OpenMP runtime.
#     266
#     267   * You are running 32-bit Python on a 64-bit OS
#     268
#     269 Error message(s): {os_error_list}
#     270 """
#     271         )
#     272     _register_log_callback(lib)
#     274     libver = _lib_version(lib)
#
# XGBoostError:
# XGBoost Library (libxgboost.dylib) could not be loaded.
# Likely causes:
#   * OpenMP runtime is not installed
#     - vcomp140.dll or libgomp-1.dll for Windows
#     - libomp.dylib for Mac OSX
#     - libgomp.so for Linux and other UNIX-like OSes
#     Mac OSX users: Run `brew install libomp` to install OpenMP runtime.
#
#   * You are running 32-bit Python on a 64-bit OS
#
# Error message(s): ["dlopen(/Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages/xgboost/lib/libxgboost.dylib, 0x0006): Library not loaded: @rpath/libomp.dylib\n  Referenced from: <98D50080-9632-3EA4-B874-146E55453763> /Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/python3.10/site-packages/xgboost/lib/libxgboost.dylib\n  Reason: tried: '/opt/homebrew/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/opt/libomp/lib/libomp.dylib' (no such file), '/opt/homebrew/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/opt/libomp/lib/libomp.dylib' (no such file), '/Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/libomp.dylib' (no such file), '/opt/homebrew/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/lib/libomp.dylib' (no such file), '/Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/gvijaykumarachary/.pyenv/versions/3.10.13/lib/libomp.dylib' (no such file), '/opt/homebrew/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/lib/libomp.dylib' (no such file)"]

# %%
# Step 1: Create an imbalanced binary classification dataset
X, y = make_classification(n_samples=1000, n_features=10, n_informative=2, n_redundant=8, 
                           weights=[0.9, 0.1], flip_y=0, random_state=42)

np.unique(y, return_counts=True)
# Out:
# (array([0, 1]), array([900, 100]))

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# %% [markdown]
# ### Experiment 1: Train Logistic Regression Classifier

# %%
log_reg = LogisticRegression(C=1, solver='liblinear')
log_reg.fit(X_train, y_train)
y_pred_log_reg = log_reg.predict(X_test)
print(classification_report(y_test, y_pred_log_reg))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95       270
#            1       0.60      0.50      0.55        30
#
#     accuracy                           0.92       300
#    macro avg       0.77      0.73      0.75       300
# weighted avg       0.91      0.92      0.91       300

# %% [markdown]
# ### Experiment 2: Train Random Forest Classifier

# %%
rf_clf = RandomForestClassifier(n_estimators=30, max_depth=3)
rf_clf.fit(X_train, y_train)
y_pred_rf = rf_clf.predict(X_test)
print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       270
#            1       0.95      0.70      0.81        30
#
#     accuracy                           0.97       300
#    macro avg       0.96      0.85      0.89       300
# weighted avg       0.97      0.97      0.96       300

# %% [markdown]
# ### Experiment 3: Train XGBoost

# %%
xgb_clf = XGBClassifier(use_label_encoder=False, eval_metric='logloss')
xgb_clf.fit(X_train, y_train)
y_pred_xgb = xgb_clf.predict(X_test)
print(classification_report(y_test, y_pred_xgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       270
#            1       0.96      0.80      0.87        30
#
#     accuracy                           0.98       300
#    macro avg       0.97      0.90      0.93       300
# weighted avg       0.98      0.98      0.98       300

# %% [markdown]
# ### Experiment 4: Handle class imbalance using SMOTETomek and then Train XGBoost

# %%
from imblearn.combine import SMOTETomek

smt = SMOTETomek(random_state=0)
X_train_res, y_train_res = smt.fit_resample(X_train, y_train)

np.unique(y_train_res, return_counts=True)
# Out:
# (array([0, 1]), array([613, 613]))

# %%
xgb_clf = XGBClassifier(use_label_encoder=False, eval_metric='logloss')
xgb_clf.fit(X_train_res, y_train_res)
y_pred_xgb = xgb_clf.predict(X_test)
print(classification_report(y_test, y_pred_xgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98       270
#            1       0.76      0.83      0.79        30
#
#     accuracy                           0.96       300
#    macro avg       0.87      0.90      0.88       300
# weighted avg       0.96      0.96      0.96       300

# %% [markdown]
# <h2 align="center" style="color:blue">Track Experiments Using MLFlow</h2>

# %%
models = [
    (
        "Logistic Regression", 
        LogisticRegression(C=1, solver='liblinear'), 
        (X_train, y_train),
        (X_test, y_test)
    ),
    (
        "Random Forest", 
        RandomForestClassifier(n_estimators=30, max_depth=3), 
        (X_train, y_train),
        (X_test, y_test)
    ),
    (
        "XGBClassifier",
        XGBClassifier(use_label_encoder=False, eval_metric='logloss'), 
        (X_train, y_train),
        (X_test, y_test)
    ),
    (
        "XGBClassifier With SMOTE",
        XGBClassifier(use_label_encoder=False, eval_metric='logloss'), 
        (X_train_res, y_train_res),
        (X_test, y_test)
    )
]

# %%
reports = []

for model_name, model, train_set, test_set in models:
    X_train = train_set[0]
    y_train = train_set[1]
    X_test = test_set[0]
    y_test = test_set[1]
    
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    report = classification_report(y_test, y_pred, output_dict=True)
    reports.append(report)

# %%
import mlflow
import mlflow.sklearn
import mlflow.xgboost

# %%
# Initialize MLflow
mlflow.set_experiment("imbalanced classification")
mlflow.set_tracking_uri("http://localhost:5000")

for i, element in enumerate(models):
    model_name = element[0]
    model = element[1]
    report = reports[i]
    
    with mlflow.start_run(run_name=model_name):        
        mlflow.log_param("model", model_name)
        mlflow.log_metric('accuracy', report['accuracy'])
        mlflow.log_metric('recall_class_1', report['1']['recall'])
        mlflow.log_metric('recall_class_0', report['0']['recall'])
        mlflow.log_metric('f1_score_macro', report['macro avg']['f1-score'])        
        
        if "XGB" in model_name:
            mlflow.xgboost.log_model(model, "model")
        else:
            mlflow.sklearn.log_model(model, "model")
# Out:
# 2025/05/28 19:18:04 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run Logistic Regression at: http://localhost:5000/#/experiments/146567435224915687/runs/cbc2666eddce4732ad0fc1863f7760fa
# 🧪 View experiment at: http://localhost:5000/#/experiments/146567435224915687
# 2025/05/28 19:18:14 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run Random Forest at: http://localhost:5000/#/experiments/146567435224915687/runs/bb6a77e530474ac7895a14dd8e57436d
# 🧪 View experiment at: http://localhost:5000/#/experiments/146567435224915687
# 2025/05/28 19:18:24 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run XGBClassifier at: http://localhost:5000/#/experiments/146567435224915687/runs/685c0cb7a8e7450bb166a11d47d10118
# 🧪 View experiment at: http://localhost:5000/#/experiments/146567435224915687
# 2025/05/28 19:18:36 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run XGBClassifier With SMOTE at: http://localhost:5000/#/experiments/146567435224915687/runs/320e11b65fc94fd3b9f4069446e46776
# 🧪 View experiment at: http://localhost:5000/#/experiments/146567435224915687
