# %%
import numpy as np

# %%
np.__version__
# Out:
# '1.26.4'

# %%
import sys
sys.version
# Out:
# '3.10.13 (main, Jun  7 2025, 17:52:05) [Clang 17.0.0 (clang-1700.0.13.5)]'

# %%
my_list = [1, 2, 3]
my_list
# Out:
# [1, 2, 3]

# %%
type(my_list)
# Out:
# list

# %%
arr = np.array(my_list)
arr
# Out:
# array([1, 2, 3])

# %%
type(arr)
# Out:
# numpy.ndarray
