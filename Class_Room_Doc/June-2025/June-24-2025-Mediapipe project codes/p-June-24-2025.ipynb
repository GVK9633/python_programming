# %%
# https://ai.google.dev/edge/mediapipe/solutions/guide
# https://mediapipe-studio.webapps.google.com/studio/demo/object_detectorhttps://mediapipe-studio.webapps.google.com/studio/demo/object_detector

# https://github.com/kodigitaccount/MEDIAPIPE-LIBRARY
