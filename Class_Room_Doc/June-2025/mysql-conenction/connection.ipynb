# %%
import mysql.connector

conn=mysql.connector.connect(
    host='localhost',
    user='root',
    password='root123')
if conn.is_connected():
    print("Connected to MySQL Server")
else:
    print("Failed to connect to MySQL Server")
cursor=conn.cursor()
cursor.execute("CREATE DATABASE IF NOT EXISTS test_db")
cursor.execute("USE test_db")
print(cursor)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/mysql/connector/connection_cext.py:354, in CMySQLConnection._open_connection(self)
#     353 try:
# --> 354     self._cmysql.connect(**cnx_kwargs)
#     355     self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Can't connect to MySQL server on 'localhost:3306' (61)
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[5], line 3
#       1 import mysql.connector
# ----> 3 conn=mysql.connector.connect(
#       4     host='localhost',
#       5     user='root',
#       6     password='root123')
#       7 if conn.is_connected():
#       8     print("Connected to MySQL Server")
#
# ...

# %%
import mysql.connector
conn= mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="test_db")
cursor = conn.cursor()
cursor.execute("SELECT * FROM test_table")
for row in cursor.fetchall():
    print(row)
cursor.close()
conn.close()
# This script connects to a MySQL database, retrieves all records from a specified table, and prints them.
# Make sure to replace 'test_db' and 'test_table' with your actual database and table names.
# Ensure you have the mysql-connector-python package installed:
# pip install mysql-connector-python
# Note: This script assumes that the MySQL server is running locally and that the user 'root' has access to the database.
# If you encounter any issues, check your MySQL server status and credentials.
# You can also modify the connection parameters as needed for your environment.
# Ensure that the MySQL server is running and accessible.
# If you need to handle exceptions, consider wrapping the connection and query execution in a try-except block.
# Example of handling exceptions
# try:
#     conn = mysql.connector.connect(
#         host="localhost",
#         user
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/mysql/connector/connection_cext.py:354, in CMySQLConnection._open_connection(self)
#     353 try:
# --> 354     self._cmysql.connect(**cnx_kwargs)
#     355     self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Can't connect to MySQL server on 'localhost:3306' (61)
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[3], line 2
#       1 import mysql.connector
# ----> 2 conn= mysql.connector.connect(
#       3     host="localhost",
#       4     user="root",
#       5     password="",
#       6     database="test_db")
#       7 cursor = conn.cursor()
#       8 cursor.execute("SELECT * FROM test_table")
#
# ...
