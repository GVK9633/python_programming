# %%
# !pip install mlflow
# Out:
# ...
#   Using cached cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# ...
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# ...
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.7/24.7 MB 38.4 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 6.2 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 733.8/733.8 kB 8.6 MB/s eta 0:00:00
# ...
# Using cached cachetools-5.5.2-py3-none-any.whl (10 kB)
# ...
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# ...
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# ...
#   Attempting uninstall: cachetools90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  7/26 [graphql-core]
#     Found existing installation: cachetools 6.1.0━━━━━━━━━━━━━  7/26 [graphql-core]
# ...

# %%
# !pip install mlops
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 37.3 MB/s eta 0:00:00
# ...
#   DEPRECATION: Building 'mlops' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'mlops'. Discussion can be found at https://github.com/pypa/pip/issues/6334
# ...
#   Created wheel for mlops: filename=mlops-0.1.0-py3-none-any.whl size=3542 sha256=ae6ebeab92b58fd96d617bc26a153371b6177ddd91b2c7367df7083944071bfd
#   Stored in directory: /Users/gvijaykumarachary/Library/Caches/pip/wheels/37/5d/e3/1829ad232de1c8d77a6b94f5e134c5c5d6eef2f8fc89b8ee83
# Successfully built mlops
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [mlops]32m2/5 [tf-keras]
# ...

# %%
# !pip install mlflow ui
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement ui (from versions: none)
# ERROR: No matching distribution found for ui
