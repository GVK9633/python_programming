# %%
# https://www.ultralytics.com
# https://docs.ultralytics.com
# https://docs.ultralytics.com/modes/
# https://docs.ultralytics.com/tasks/

# %%
import ultralytics 
ultralytics.checks() # checks for updates, dependencies, and environment
# Out:
# Ultralytics 8.3.159 🚀 Python-3.10.13 torch-2.7.1 CPU (Apple M4)
# Setup complete ✅ (10 CPUs, 24.0 GB RAM, 93.6/460.4 GB disk)

# %%
import os
print(os.path.exists("./traffic.jpg"))
# Out:
# True

# %%
import lzma
model = ultralytics.YOLO("yolov8n.pt")  # load a pretrained YOLOv8n model
results = model.predict(source=r"/Users/gvijaykumarachary/Desktop/MyComputer/E-Drive/DataScience/Repos/python_programming/Class_Room_Doc/June-2025/June-26-2025/traffic.jpg", save=True)  # predict on an image and save results
print(results)  # print results to console
print(results[0].numpy())  # print results for the first image
# Out:
# image 1/1 /Users/gvijaykumarachary/Desktop/MyComputer/E-Drive/DataScience/Repos/python_programming/Class_Room_Doc/June-2025/June-26-2025/traffic.jpg: 448x640 16 cars, 5 buss, 3 trucks, 30.7ms
# Speed: 1.8ms preprocess, 30.7ms inference, 3.3ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict2
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...
