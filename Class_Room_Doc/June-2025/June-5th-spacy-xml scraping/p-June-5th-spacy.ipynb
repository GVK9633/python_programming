# %%
#pip3 install spacy

# %%
#python -m spacy download en_core_web_sm
#https://spacy.io/usage/spacy-101
# python3 -m spacy download en_core_web_sm
#python3 -m spacy download en_core_web_sm  (small model)
#python3 -m spacy download en_core_web_md (medium model)
#python3 -m spacy download en_core_web_lg (large model)

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp("Apple is looking at buying U.K. startup for $1 billion")

for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Apple 0 5 ORG
# U.K. 27 31 GPE
# $1 billion 44 54 MONEY

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
text = "Apple is looking at buying U.K. startup for $1 billion"

doc = nlp(text)
doc
# Out:
# Apple is looking at buying U.K. startup for $1 billion

# %%
for ent in doc.ents:
    # print(token.text, token.pos_, token.dep_, token.head.text)
    print(f"ent.text: {ent.text}, ent.label_: {ent.label_}, ent.start_char: {ent.start_char}, ent.end_char: {ent.end_char}")
# Out:
# ent.text: Apple, ent.label_: ORG, ent.start_char: 0, ent.end_char: 5
# ent.text: U.K., ent.label_: GPE, ent.start_char: 27, ent.end_char: 31
# ent.text: $1 billion, ent.label_: MONEY, ent.start_char: 44, ent.end_char: 54

# %%
for token in doc:
    print(token.text, token.pos_, token.dep_, token.head.text)
# Out:
# Apple PROPN nsubj looking
# is AUX aux looking
# looking VERB ROOT looking
# at ADP prep looking
# buying VERB pcomp at
# U.K. PROPN nsubj startup
# startup VERB ccomp buying
# for ADP prep startup
# $ SYM quantmod billion
# 1 NUM compound billion
# billion NUM pobj for

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
text = "data science and ai & gen ai has greater career ahead"
doc = nlp(text)

# %%
doc
# Out:
# data science and ai & gen ai has greater career ahead

# %%
for token in doc:
    print(f"token.text: {token.text}, token.pos_: {token.pos_}, token.dep_: {token.dep_}, token.head.text: {token.head.text}")
# Out:
# token.text: data, token.pos_: NOUN, token.dep_: compound, token.head.text: science
# token.text: science, token.pos_: NOUN, token.dep_: nsubj, token.head.text: ai
# token.text: and, token.pos_: CCONJ, token.dep_: cc, token.head.text: science
# token.text: ai, token.pos_: PROPN, token.dep_: conj, token.head.text: science
# token.text: &, token.pos_: CCONJ, token.dep_: cc, token.head.text: ai
# token.text: gen, token.pos_: PROPN, token.dep_: conj, token.head.text: ai
# token.text: ai, token.pos_: PROPN, token.dep_: nsubj, token.head.text: has
# token.text: has, token.pos_: VERB, token.dep_: ROOT, token.head.text: has
# token.text: greater, token.pos_: ADJ, token.dep_: amod, token.head.text: career
# token.text: career, token.pos_: NOUN, token.dep_: dobj, token.head.text: has
# token.text: ahead, token.pos_: ADV, token.dep_: advmod, token.head.text: has

# %%
for token in doc:
    print(f"token.text: {token.text}")
# Out:
# token.text: data
# token.text: science
# token.text: and
# token.text: ai
# token.text: &
# token.text: gen
# token.text: ai
# token.text: has
# token.text: greater
# token.text: career
# token.text: ahead

# %%
for token in doc:
    print(f"token.part of speech: {token.pos_}")
# Out:
# token.part of speech: NOUN
# token.part of speech: NOUN
# token.part of speech: CCONJ
# token.part of speech: PROPN
# token.part of speech: CCONJ
# token.part of speech: PROPN
# token.part of speech: PROPN
# token.part of speech: VERB
# token.part of speech: ADJ
# token.part of speech: NOUN
# token.part of speech: ADV

# %%
for token in doc:
    print(token.text,token.lemma,token.tag_,token.shape_,token.is_alpha, token.pos_, token.dep_, token.head.text)
# Out:
# data 6645506661261177361 NN xxxx True NOUN compound science
# science 15907409978124634296 NN xxxx True NOUN nsubj ai
# and 2283656566040971221 CC xxx True CCONJ cc science
# ai 4489555979637837711 NNP xx True PROPN conj science
# & 15473034735919704609 CC & False CCONJ cc ai
# gen 11090586419576673076 NNP xxx True PROPN conj ai
# ai 4489555979637837711 NNP xx True PROPN nsubj has
# has 14692702688101715474 VBZ xxx True VERB ROOT has
# greater 8881679497796027013 JJR xxxx True ADJ amod career
# career 16267834800013645067 NN xxxx True NOUN dobj has
# ahead 10555556397075732372 RB xxxx True ADV advmod has

# %%
newText = """There are broadly two types of extractive summarization tasks depending on what the summarization program focuses on. The first is generic summarization, which focuses on obtaining a generic summary or abstract of the collection (whether documents, or sets of images, or videos, news stories etc.). The second is query relevant summarization, sometimes called query-based summarization, which summarizes objects specific to a query. Summarization systems are able to create both query relevant text summaries and generic machine-generated summaries depending on what the user needs.
An example of a summarization problem is document summarization, which attempts to automatically produce an abstract from a given document. Sometimes one might be interested in generating a summary from a single source document, while others can use multiple source documents (for example, a cluster of articles on the same topic). This problem is called multi-document summarization. A related application is summarizing news articles. Imagine a system, which automatically pulls together news articles on a given topic (from the web), and concisely represents the latest news as a summary.
Image collection summarization is another application example of automatic summarization. It consists in selecting a representative set of images from a larger set of images.[4] A summary in this context is useful to show the most representative images of results in an image collection exploration system. Video summarization is a related domain, where the system automatically creates a trailer of a long video. This also has applications in consumer or personal videos, where one might want to skip the boring or repetitive actions. Similarly, in surveillance videos, one would want to extract important and suspicious activity, while ignoring all the boring and redundant frames captured """

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation

# %%
stopwords = list(STOP_WORDS)
stopwords
# Out:
# ['he',
#  'our',
#  'just',
#  'doing',
#  'one',
#  'although',
#  'n‘t',
#  'namely',
#  'me',
#  'really',
#  'throughout',
#  'noone',
#  'done',
#  '‘s',
#  'since',
#  'due',
#  'before',
#  'latter',
#  'for',
#  'while',
#  'wherever',
#  'too',
#  'beside',
#  'often',
#  'six',
#  'then',
#  'between',
#  'about',
#  'on',
#  'than',
#  'their',
#  'ca',
#  "'s",
#  'anything',
#  'beyond',
#  'everything',
#  'least',
#  'part',
#  'being',
#  'hereafter',
#  'also',
#  'anywhere',
#  'once',
#  'therefore',
#  'call',
#  'whose',
#  'to',
#  'towards',
#  'perhaps',
#  'moreover',
#  'because',
#  'yours',
#  'along',
#  'can',
#  'now',
#  'eleven',
#  'wherein',
#  'own',
#  'yourself',
#  'as',
#  'quite',
#  'no',
#  'someone',
#  'be',
#  'was',
#  'get',
#  'is',
#  "'ve",
#  'were',
#  'much',
#  'cannot',
#  'seems',
#  'without',
#  "'m",
#  '‘ll',
#  'first',
#  'off',
#  "'ll",
#  'either',
#  '’re',
#  'whereafter',
#  'not',
#  'your',
#  'ourselves',
# ...

# %%
len(stopwords)
# Out:
# 326

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp(newText)
doc
# Out:
# There are broadly two types of extractive summarization tasks depending on what the summarization program focuses on. The first is generic summarization, which focuses on obtaining a generic summary or abstract of the collection (whether documents, or sets of images, or videos, news stories etc.). The second is query relevant summarization, sometimes called query-based summarization, which summarizes objects specific to a query. Summarization systems are able to create both query relevant text summaries and generic machine-generated summaries depending on what the user needs.
# ...

# %%
tokens = [token.text for token in doc]
tokens
# Out:
# ['There',
#  'are',
#  'broadly',
#  'two',
#  'types',
#  'of',
#  'extractive',
#  'summarization',
#  'tasks',
#  'depending',
#  'on',
#  'what',
#  'the',
#  'summarization',
#  'program',
#  'focuses',
#  'on',
#  '.',
#  'The',
#  'first',
#  'is',
#  'generic',
#  'summarization',
#  ',',
#  'which',
#  'focuses',
#  'on',
#  'obtaining',
#  'a',
#  'generic',
#  'summary',
#  'or',
#  'abstract',
#  'of',
#  'the',
#  'collection',
#  '(',
#  'whether',
#  'documents',
#  ',',
#  'or',
#  'sets',
#  'of',
#  'images',
#  ',',
#  'or',
#  'videos',
#  ',',
#  'news',
#  'stories',
#  'etc',
#  '.',
#  ')',
#  '.',
#  'The',
#  'second',
#  'is',
#  'query',
#  'relevant',
#  'summarization',
#  ',',
#  'sometimes',
#  'called',
#  'query',
#  '-',
#  'based',
#  'summarization',
#  ',',
#  'which',
#  'summarizes',
#  'objects',
#  'specific',
#  'to',
#  'a',
#  'query',
#  '.',
#  'Summarization',
#  'systems',
#  'are',
#  'able',
#  'to',
#  'create',
#  'both',
# ...

# %%
#use case can you summarize the paragraph and suggest me the importance from the text
# how to find out the important words from the text
#based on the frequency of the words
# para = sentnece
# sentence= token
#token score = frequency of the word in the paragraph

# %%
word_frequencies = {}
for word in doc:
    if word.text.lower() not in stopwords and word.text not in punctuation:
        if word.text not in word_frequencies.keys():
            word_frequencies[word.text] = 1
        else:
            word_frequencies[word.text] += 1
word_frequencies
# Out:
# {'broadly': 1,
#  'types': 1,
#  'extractive': 1,
#  'summarization': 11,
#  'tasks': 1,
#  'depending': 2,
#  'program': 1,
#  'focuses': 2,
#  'generic': 3,
#  'obtaining': 1,
#  'summary': 4,
#  'abstract': 2,
#  'collection': 3,
#  'documents': 2,
#  'sets': 1,
#  'images': 3,
#  'videos': 3,
#  'news': 4,
#  'stories': 1,
#  'etc': 1,
#  'second': 1,
#  'query': 4,
#  'relevant': 2,
#  'called': 2,
#  'based': 1,
#  'summarizes': 1,
#  'objects': 1,
#  'specific': 1,
#  'Summarization': 1,
#  'systems': 1,
#  'able': 1,
#  'create': 1,
#  'text': 1,
#  'summaries': 2,
#  'machine': 1,
#  'generated': 1,
#  'user': 1,
#  'needs': 1,
#  '\n': 2,
#  'example': 3,
#  'problem': 2,
#  'document': 4,
#  'attempts': 1,
#  'automatically': 3,
#  'produce': 1,
#  'given': 2,
#  'interested': 1,
#  'generating': 1,
#  'single': 1,
#  'source': 2,
#  'use': 1,
#  'multiple': 1,
#  'cluster': 1,
#  'articles': 3,
#  'topic': 2,
#  'multi': 1,
#  'related': 2,
#  'application': 2,
# ...

# %%
len(word_frequencies)
# Out:
# 103

# %%
max_frequency = max(word_frequencies.values())
max_frequency
# Out:
# 11

# %%
# waieghted frequency is 11 with all the words
## 1/11,2/11
for word in word_frequencies.keys():
    word_frequencies[word] = word_frequencies[word] / max_frequency

# %%
word_frequencies
# Out:
# {'broadly': 0.09090909090909091,
#  'types': 0.09090909090909091,
#  'extractive': 0.09090909090909091,
#  'summarization': 1.0,
#  'tasks': 0.09090909090909091,
#  'depending': 0.18181818181818182,
#  'program': 0.09090909090909091,
#  'focuses': 0.18181818181818182,
#  'generic': 0.2727272727272727,
#  'obtaining': 0.09090909090909091,
#  'summary': 0.36363636363636365,
#  'abstract': 0.18181818181818182,
#  'collection': 0.2727272727272727,
#  'documents': 0.18181818181818182,
#  'sets': 0.09090909090909091,
#  'images': 0.2727272727272727,
#  'videos': 0.2727272727272727,
#  'news': 0.36363636363636365,
#  'stories': 0.09090909090909091,
#  'etc': 0.09090909090909091,
#  'second': 0.09090909090909091,
#  'query': 0.36363636363636365,
#  'relevant': 0.18181818181818182,
#  'called': 0.18181818181818182,
#  'based': 0.09090909090909091,
#  'summarizes': 0.09090909090909091,
#  'objects': 0.09090909090909091,
#  'specific': 0.09090909090909091,
# ...

# %%
sentence_tokens = [sent for sent in doc.sents]
sentence_tokens
# Out:
# [There are broadly two types of extractive summarization tasks depending on what the summarization program focuses on.,
#  The first is generic summarization, which focuses on obtaining a generic summary or abstract of the collection (whether documents, or sets of images, or videos, news stories etc.).,
#  The second is query relevant summarization, sometimes called query-based summarization, which summarizes objects specific to a query.,
#  Summarization systems are able to create both query relevant text summaries and generic machine-generated summaries depending on what the user needs.,
#  An example of a summarization problem is document summarization, which attempts to automatically produce an abstract from a given document.,
#  Sometimes one might be interested in generating a summary from a single source document, while others can use multiple source documents (for example, a cluster of articles on the same topic).,
#  This problem is called multi-document summarization.,
# ...

# %%
len(sentence_tokens)
# Out:
# 15

# %%
sentence_tokens
# Out:
# [There are broadly two types of extractive summarization tasks depending on what the summarization program focuses on.,
#  The first is generic summarization, which focuses on obtaining a generic summary or abstract of the collection (whether documents, or sets of images, or videos, news stories etc.).,
#  The second is query relevant summarization, sometimes called query-based summarization, which summarizes objects specific to a query.,
#  Summarization systems are able to create both query relevant text summaries and generic machine-generated summaries depending on what the user needs.,
#  An example of a summarization problem is document summarization, which attempts to automatically produce an abstract from a given document.,
#  Sometimes one might be interested in generating a summary from a single source document, while others can use multiple source documents (for example, a cluster of articles on the same topic).,
#  This problem is called multi-document summarization.,
# ...

# %%
sentence_scores = {}
for sent in sentence_tokens:
    for word in sent:
        if word.text.lower() in word_frequencies.keys():
            if sent not in sentence_scores.keys():
                sentence_scores[sent] = word_frequencies[word.text.lower()]
            else:
                sentence_scores[sent] += word_frequencies[word.text.lower()]
sentence_scores
# Out:
# {There are broadly two types of extractive summarization tasks depending on what the summarization program focuses on.: 2.818181818181818,
#  The first is generic summarization, which focuses on obtaining a generic summary or abstract of the collection (whether documents, or sets of images, or videos, news stories etc.).: 3.9999999999999987,
#  The second is query relevant summarization, sometimes called query-based summarization, which summarizes objects specific to a query.: 3.909090909090909,
#  Summarization systems are able to create both query relevant text summaries and generic machine-generated summaries depending on what the user needs.: 3.2727272727272716,
#  An example of a summarization problem is document summarization, which attempts to automatically produce an abstract from a given document.: 3.9999999999999996,
# ...

# %%
len(sentence_scores)
# Out:
# 15

# %%
# larest sentence and lower setnence
from heapq import nlargest

# %%
#15
select_length = int(len(sentence_tokens) * 0.4)
select_length
# Out:
# 6

# %%
#sorting the sentence scores and selecting the top sentences
summary_sentences = nlargest(select_length, sentence_scores, key=sentence_scores.get)
summary_sentences
# Out:
# [An example of a summarization problem is document summarization, which attempts to automatically produce an abstract from a given document.,
#  The first is generic summarization, which focuses on obtaining a generic summary or abstract of the collection (whether documents, or sets of images, or videos, news stories etc.).,
#  The second is query relevant summarization, sometimes called query-based summarization, which summarizes objects specific to a query.,
#  Summarization systems are able to create both query relevant text summaries and generic machine-generated summaries depending on what the user needs.,
#  Image collection summarization is another application example of automatic summarization.,
#  Imagine a system, which automatically pulls together news articles on a given topic (from the web), and concisely represents the latest news as a summary.]

# %%
finalsummary = ' '.join([word.text for word in summary_sentences])
print(finalsummary)
# Out:
# An example of a summarization problem is document summarization, which attempts to automatically produce an abstract from a given document. The first is generic summarization, which focuses on obtaining a generic summary or abstract of the collection (whether documents, or sets of images, or videos, news stories etc.). The second is query relevant summarization, sometimes called query-based summarization, which summarizes objects specific to a query. Summarization systems are able to create both query relevant text summaries and generic machine-generated summaries depending on what the user needs.
#  Image collection summarization is another application example of automatic summarization. Imagine a system, which automatically pulls together news articles on a given topic (from the web), and concisely represents the latest news as a summary.

# %%
#word cloud
from wordcloud import wordcloud
from matplotlib import pyplot as plt

# %%
wordcloud = wordcloud.WordCloud(width=800, height=400, background_color='black',colormap='Accent').generate(finalsummary)

# %%
plt.imshow(wordcloud, interpolation='quadric')
plt.axis('off')
plt.show()
